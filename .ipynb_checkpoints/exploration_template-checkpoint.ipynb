# %% [markdown]
# # Premier League Analytics
# ## by Mathias Brønd Sørensen
#
# ## Preliminary Wrangling
#
# The dataset is describing football matches, players and teams from Europe and is obtained from [Kaggle](https://www.kaggle.com/hugomathien/soccer).
#
# The data is organized in a third normalized relational database, why the first task will be to wrangle the data into a 'tidy' dataset.
#
# As my own personal favorite is the English Premier League, the analysis will focus on this and hopefully we'll find some insights that will also suprise me!

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import sqlalchemy as sql
import re as re

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# %matplotlib inline

# %%
# Create a sql engine
engine = sql.create_engine('sqlite:///database.sqlite')

# %%
# Connect to the engine
connection = engine.connect()

# %%
# Inspect the tables in the database
inspector = sql.inspect(engine)
for table_name in inspector.get_table_names():
    print("Table: %s" % table_name)
# Out:
# Table: Country
# Table: League
# Table: Match
# Table: Player
# Table: Player_Attributes
# Table: Team
# Table: Team_Attributes
# Table: sqlite_sequence

# %%
# Load data into Pandas dataframes
matches = pd.read_sql_table(table_name = 'Match', con = connection)
league = pd.read_sql_table(table_name = 'League', con = connection)
team = pd.read_sql_table(table_name = 'Team', con = connection)

# %%
matches.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# ...

# %%
league
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
team.head()
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %% [markdown]
# In order to get this dataset tidy, we want each row to represent a single game and we want it denormalized so all the information regarding that specific game is provided in the columns. This means joining the dataframes and getting rid of all the foreign keys to limit the data we will be working on in the following.
#
# **Tasks:**
# 1. Limit the matches dataframe to only contain matches from the England Premier League
# 2. Get the team long name for both the home and away team
# 3. Remove excess ID columns

# %%
# Create a new dataframe as a subset of the matches
# Id for Premier Leauge is 1729
PL_matches = matches.query('country_id == 1729')
PL_matches.head()
# Out:
#         id  country_id  league_id     season  stage                 date  \
# 1728  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1729  1730        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 1730  1731        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 1731  1732        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 1732  1733        1729       1729  2008/2009      1  2008-08-17 00:00:00
#
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 1728        489042             10260             10261               1  ...
# 1729        489043              9825              8659               1  ...
# 1730        489044              8472              8650               0  ...
# 1731        489045              8654              8528               2  ...
# 1732        489046             10252              8456               4  ...
#
#         SJA   VCH  VCD    VCA   GBH   GBD   GBA   BSH   BSD    BSA
# ...

# %%
# Getting the home team name
PL_matches = PL_matches.merge(team[['team_api_id','team_long_name']], how = 'inner', left_on = 'home_team_api_id', right_on = 'team_api_id')
PL_matches.rename(index=str, columns={"team_long_name": "home_team"},inplace=True)

# %%
# Getting the away team name
PL_matches = PL_matches.merge(team[['team_api_id','team_long_name']], how = 'inner', left_on = 'away_team_api_id', right_on = 'team_api_id')
PL_matches.rename(index=str, columns={"team_long_name": "away_team"},inplace=True)

# %%
PL_matches.head()
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        489042             10260             10261               1  ...
# 1        839802             10260             10261               3  ...
# 2       1024845             10260             10261               1  ...
# 3       1229300             10260             10261               4  ...
# 4       1474518             10260             10261               0  ...
#
#     GBH   GBD   GBA   BSH   BSD   BSA  team_api_id_x          home_team  \
# ...

# %%
PL_matches.drop(axis=1, 
                columns=['country_id','league_id','match_api_id','home_team_api_id','away_team_api_id','team_api_id_y','team_api_id_x'], 
                inplace = True)
PL_matches.head()
# Out:
#      id     season  stage                 date  home_team_goal  \
# 0  1729  2008/2009      1  2008-08-17 00:00:00               1
# 1  2494  2010/2011      1  2010-08-16 00:00:00               3
# 2  2913  2011/2012     13  2011-11-26 00:00:00               1
# 3  3353  2012/2013     19  2012-12-26 00:00:00               4
# 4  3693  2013/2014     15  2013-12-07 00:00:00               0
#
#    away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0               1             1.0             2.0             4.0
# 1               0             1.0             2.0             4.0
# 2               1             1.0             2.0             4.0
# 3               3             1.0             2.0             4.0
# 4               1             1.0             2.0             4.0
#
#    home_player_X4  ...   VCD    VCA   GBH   GBD   GBA   BSH   BSD   BSA  \
# 0             6.0  ...  5.50  12.00  1.30  4.75  10.0  1.29  4.50  11.0
# ...

# %% [markdown]
# The dataset still contains 112 variables, so lets remove the players features to limit the analysis.

# %%
# Finding all columns containing players
col_list = []
for i in PL_matches.columns:
    # Finding columns containg player in the name
    if re.findall('player', i):
        col_list.append(i)
PL_matches.drop(axis = 1, columns = col_list, inplace = True)
PL_matches.head()
# Out:
#      id     season  stage                 date  home_team_goal  \
# 0  1729  2008/2009      1  2008-08-17 00:00:00               1
# 1  2494  2010/2011      1  2010-08-16 00:00:00               3
# 2  2913  2011/2012     13  2011-11-26 00:00:00               1
# 3  3353  2012/2013     19  2012-12-26 00:00:00               4
# 4  3693  2013/2014     15  2013-12-07 00:00:00               0
#
#    away_team_goal                                               goal  \
# 0               1  <goal><value><comment>n</comment><stats><goals...
# 1               0  <goal><value><comment>n</comment><stats><goals...
# 2               1  <goal><value><comment>n</comment><stats><goals...
# 3               3  <goal><value><comment>n</comment><stats><goals...
# 4               1  <goal><value><comment>n</comment><stats><goals...
#
#                                               shoton  \
# 0  <shoton><value><stats><blocked>1</blocked></st...
# 1  <shoton><value><stats><blocked>1</blocked></st...
# ...

# %%
PL_matches.columns
# Out:
# Index(['id', 'season', 'stage', 'date', 'home_team_goal', 'away_team_goal',
#        'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner',
#        'possession', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH',
#        'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD',
#        'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'GBH', 'GBD', 'GBA',
#        'BSH', 'BSD', 'BSA', 'home_team', 'away_team'],
#       dtype='object')

# %% [markdown]
# Let's also remove the columns with XML.

# %%
PL_matches.drop(axis = 1, columns = ['goal','shoton','shotoff','foulcommit','card','cross','corner','possession'], inplace = True)
PL_matches.head()
# Out:
#      id     season  stage                 date  home_team_goal  \
# 0  1729  2008/2009      1  2008-08-17 00:00:00               1
# 1  2494  2010/2011      1  2010-08-16 00:00:00               3
# 2  2913  2011/2012     13  2011-11-26 00:00:00               1
# 3  3353  2012/2013     19  2012-12-26 00:00:00               4
# 4  3693  2013/2014     15  2013-12-07 00:00:00               0
#
#    away_team_goal  B365H  B365D  B365A   BWH  ...   VCD    VCA   GBH   GBD  \
# 0               1   1.29   5.50   11.0  1.30  ...  5.50  12.00  1.30  4.75
# 1               0   1.25   5.50   15.0  1.22  ...  6.00  15.00  1.23  5.50
# 2               1   1.40   4.50    8.5  1.37  ...  4.75   9.50  1.35  4.50
# 3               3   1.22   6.50   13.0  1.22  ...  6.50  13.00  1.22  6.50
# 4               1   1.53   4.33    7.0  1.53  ...  4.50   6.25   NaN   NaN
#
#     GBA   BSH   BSD   BSA          home_team         away_team
# 0  10.0  1.29  4.50  11.0  Manchester United  Newcastle United
# ...

# %% [markdown]
# That concludes the wrangling (for now).

# %% [markdown]
# ### What is the structure of your dataset?
#
# Each row is an English Premier League game.
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# The main features of the wrangled set are the home goals, the away goals, the stage of the season, the season, the home/away teams and the betting odds prior to the matches from multiple vendors.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# All of the remaining feature should all help us explore hidden insights!

# %% [markdown]
# ## Univariate Exploration
# We'll start of by looking at the goals for the home team and the away team.

# %%
# Set the base color to something very premier league'sk
base_color = sb.color_palette()[0]
# Create two subplots
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
sb.countplot(data = PL_matches, x = 'home_team_goal', color = base_color);
plt.xlabel('Home team goals');
plt.subplot(1,2,2)
sb.countplot(data = PL_matches, x = 'away_team_goal', color = base_color);
plt.xlabel('Away team goals');

# %% [markdown]
# Not exactly a normaldistribution, but on the other hand not surprising. The number of goals for the home team in a few games were impressive though!
#
# Let's have a look at some of the outliers:

# %%
PL_matches.query('home_team_goal > 6')[['season','stage','home_team_goal','away_team_goal','home_team','away_team']]
# Out:
#          season  stage  home_team_goal  away_team_goal          home_team  \
# 10    2012/2013     20               7               3            Arsenal
# 399   2009/2010     36               7               0            Chelsea
# 543   2009/2010     22               7               2            Chelsea
# 636   2014/2015      8               8               0        Southampton
# 683   2009/2010     38               8               0            Chelsea
# 707   2009/2010     13               9               1  Tottenham Hotspur
# 1066  2010/2011     15               7               1  Manchester United
# 1071  2011/2012     24               7               1            Arsenal
# 1493  2009/2010     32               7               1            Chelsea
# 1496  2012/2013     18               8               0            Chelsea
# 1903  2011/2012      3               8               2  Manchester United
# 2619  2013/2014     10               7               0    Manchester City
#
# ...

# %% [markdown]
# Impressive stuff! Especially from Chealse who seem to have done it multiple times. I personally remember the 8-2 Manchester United-Arsenal game (with great joy!).

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# Few games with a lot of goals, but otherwise no.
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# Data came from untidy sorces, so multiple operations were performed to get the data in a tidy format.

# %% [markdown]
# ## Bivariate Exploration
# We'll start of by looking at the relationship between home and away goals.

# %%
plt.figure(figsize = [8, 8])
# scatterplot of home/away gaols data with jitter and transparency
sb.regplot(data = PL_matches, x = 'home_team_goal', y = 'away_team_goal', fit_reg = False,
           x_jitter = 0.2, y_jitter = 0.2, scatter_kws = {'alpha' : 1/3});

# %% [markdown]
# While this is a nice visual, it's hard to tell the dense points apart. Let's try with a heatmap:

# %%
plt.figure(figsize=(8,8))
# heat map of home/away goals with bin edges between values
bins_x = np.arange(-0.5, 9.5+1, 1)
bins_y = np.arange(-0.5, 9.5+1, 1)
h2d = plt.hist2d(data = PL_matches, x = 'home_team_goal', y = 'away_team_goal',
           bins = [bins_x, bins_y])
plt.colorbar();
counts = h2d[0]

# loop through the cell counts and add text annotations for each
for i in range(counts.shape[0]):
    for j in range(counts.shape[1]):
        c = counts[i,j]
        if c >= 7: # increase visibility on darkest cells
            plt.text(bins_x[i]+0.5, bins_y[j]+0.5, int(c),
                     ha = 'center', va = 'center', color = 'white')
        elif c > 0:
            plt.text(bins_x[i]+0.5, bins_y[j]+0.5, int(c),
                     ha = 'center', va = 'center', color = 'black')
plt.xlabel('Home team goals');
plt.ylabel('Away team goals');

# %% [markdown]
# The most common result seem to be 1-1. There are some interesting findings here; it's more common for the away team to win 2-1 than 2-0 or the result ending in a draw.
#
# Next let's look at goals across the seasons:

# %%
# Season is an ordinal categorical variable, so it needs to be ordered
season_order = PL_matches.season.unique()
season_order.sort()
season_class = pd.api.types.CategoricalDtype(ordered = True, categories = season_order)
PL_matches['season'] = PL_matches['season'].astype(season_class)

# %%
# Create violin plots for the goals across seasons
plt.figure(figsize = (15,10))
plt.subplot(2,1,1)
sb.violinplot(data = PL_matches, x = 'season', y = 'home_team_goal', palette = 'Blues');
plt.subplot(2,1,2)
sb.violinplot(data = PL_matches, x = 'season', y = 'away_team_goal', palette = 'Blues');

# %% [markdown]
# The home and away team goals seem to follow the roughly the same distribution across the seasons except the 09/10 season where the home teams had a higher median of goals.
#
# Let's check out differences in goals in the different stages:

# %%
plt.figure(figsize = (15,10));
plt.subplot(2,1,1);
sb.barplot(data = PL_matches, x = 'stage', y = 'home_team_goal', color = base_color);
plt.ylim([0,2.5]);
plt.subplot(2,1,2);
sb.barplot(data = PL_matches, x = 'stage', y = 'away_team_goal', color = base_color);
plt.ylim([0,2.5]);

# %% [markdown]
# Unsurprisingly, the home team scores more, but also with more variability throughout the stages.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# Goals did not change that much from season to season, except for the home team goals in 09/10. Being an away team seems the hardest in the middle of a season as the average goals per game drops in this period.

# %% [markdown]
# ## Multivariate Exploration
# We'll start of with adding an extra categorial feature to indicate whom was the winning team.

# %%
PL_matches['winner'] = PL_matches['winner'] = np.where(
     PL_matches['home_team_goal'] > PL_matches['away_team_goal'], 
    'Home', 
     np.where(
        PL_matches['home_team_goal'] < PL_matches['away_team_goal'], 
    'Away', 'Draw'
     )
)
PL_matches.head()
# Out:
#      id     season  stage                 date  home_team_goal  \
# 0  1729  2008/2009      1  2008-08-17 00:00:00               1
# 1  2494  2010/2011      1  2010-08-16 00:00:00               3
# 2  2913  2011/2012     13  2011-11-26 00:00:00               1
# 3  3353  2012/2013     19  2012-12-26 00:00:00               4
# 4  3693  2013/2014     15  2013-12-07 00:00:00               0
#
#    away_team_goal  B365H  B365D  B365A   BWH  ...    VCA   GBH   GBD   GBA  \
# 0               1   1.29   5.50   11.0  1.30  ...  12.00  1.30  4.75  10.0
# 1               0   1.25   5.50   15.0  1.22  ...  15.00  1.23  5.50  12.0
# 2               1   1.40   4.50    8.5  1.37  ...   9.50  1.35  4.50   8.5
# 3               3   1.22   6.50   13.0  1.22  ...  13.00  1.22  6.50  11.0
# 4               1   1.53   4.33    7.0  1.53  ...   6.25   NaN   NaN   NaN
#
#     BSH   BSD   BSA          home_team         away_team  winner
# 0  1.29  4.50  11.0  Manchester United  Newcastle United    Draw
# ...

# %%
# Create a grid of scatter plots for the different seasons
plt.figure(figsize = [8, 8]);
# scatterplot of home/away gaols data with jitter and transparency
g = sb.FacetGrid(data = PL_matches, hue = 'winner', height = 5, col = 'season', col_wrap = 3);
g.map(sb.regplot, data = PL_matches, x = 'home_team_goal', y = 'away_team_goal', fit_reg = False,
           x_jitter = 0.4, y_jitter = 0.4, scatter_kws = {'alpha' : 1/5});
# Add the winning team category
g.add_legend();

# %% [markdown]
# Not a very nice visual as we have the same problems with too many datapoints clutering the image.
# Let's instead look at the results in different seasons.

# %%
plt.figure(figsize = [8, 8]);
# scatterplot of home/away gaols data with jitter and transparency
g = sb.FacetGrid(data = PL_matches, height = 5, col = 'season', col_wrap = 3);
#g.map(sb.regplot, data = PL_matches, x = 'B365H', y = 'B365A', fit_reg = False,
#           x_jitter = 0.4, y_jitter = 0.4, scatter_kws = {'alpha' : 1/3});
g.map(plt.hist2d, data = PL_matches, x = 'home_team_goal', y = 'away_team_goal',
           bins = [bins_x, bins_y])
plt.colorbar();

# %% [markdown]
# Very similar patterns in all of the seasons.
#
# How about those odds? How do they vary from vendor to vendor?

# %%
# List of variables for the different outcomes
home_odds = ['B365H', 'BWH', 'IWH', 'LBH', 'PSH', 'WHH', 'SJH', 'VCH', 'GBH', 'BSH']
draw_odds = ['B365D', 'BWD', 'IWD', 'LBD', 'PSD', 'WHD', 'SJD', 'VCD', 'GBD', 'BSD']
away_odds = ['B365A', 'BWA', 'IWA', 'LBA', 'PSA', 'WHA', 'SJA', 'VCA', 'GBA', 'BSA']

# Pair grid for all homeside-winning odds
g = sb.PairGrid(data = PL_matches, vars = home_odds);
g.map_diag(plt.hist);
g.map_offdiag(plt.scatter);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Pair grid for all draw odds
g = sb.PairGrid(data = PL_matches, vars = draw_odds);
g.map_diag(plt.hist);
g.map_offdiag(plt.scatter);

# %%
# Pair grid for all awayside-winning odds
g = sb.PairGrid(data = PL_matches, vars = away_odds);
g.map_diag(plt.hist);
g.map_offdiag(plt.scatter);

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# Goals for home and away team are very similar across the seasons in this dataset.
#
# ### Were there any interesting or surprising interactions between features?
#
# The odds from different vendors look fairly linear when they are low, but whn the increase the variability increases as well.

# %%
# Saving the cleaned dataset for explanatory analysis.
PL_matches.to_csv('PL_matches.csv')
